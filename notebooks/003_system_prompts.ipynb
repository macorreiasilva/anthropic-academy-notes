# %%
# Instalar as dependências necessárias
# %pip anthropic python-dotenv

# %%
# %pip anthropic python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "anthropic"

# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()  # take environment variables from .env.

client = Anthropic()
model = "claude-haiku-4-5-20251001"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1024,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Without system prompt
messages = []

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
add_user_message(messages, "How do I solve the equation 2x + 3 = 7?")
answer = chat(messages, system=system)

answer
# Out:
# "Great question! Let's work through this together step by step.\n\n**Step 1:** What's your goal here?\n- You want to get x by itself on one side of the equation, right?\n\n**Step 2:** Look at what's with the x.\n- You have 2x + 3 = 7\n- What number is being *added* to the 2x?\n\n**Step 3:** Once you identify that number, ask yourself:\n- What's the opposite operation of addition?\n- What would you do to both sides of the equation to remove that number?\n\nTry taking that step, and then tell me what you get. We'll continue from there! 😊"

# %%
messages = []

add_user_message(messages, "Write a Python function that checks if a string is empty for duplicate characters.")
answer = chat(messages, system="You are a Python engineer who writes very concise code.")
answer
# Out:
# '# Check if a string has duplicate characters\n\n```python\ndef has_duplicates(s: str) -> bool:\n    """Returns True if string has duplicate characters, False otherwise."""\n    return len(s) != len(set(s))\n```\n\n**Usage examples:**\n```python\nprint(has_duplicates("hello"))      # True (l appears twice)\nprint(has_duplicates("world"))      # False (no duplicates)\nprint(has_duplicates("aaa"))        # True\nprint(has_duplicates(""))           # False (empty string)\nprint(has_duplicates("a"))          # False (single char)\n```\n\n**Alternative with early exit (for large strings):**\n```python\ndef has_duplicates(s: str) -> bool:\n    """Early exit version - faster for strings with many duplicates."""\n    seen = set()\n    for char in s:\n        if char in seen:\n            return True\n        seen.add(char)\n    return False\n```\n\nThe first version is concise and Pythonic. The second is more efficient for large strings with early duplicates.'
