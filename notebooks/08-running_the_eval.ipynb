# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    answer = chat(messages, stop_sequences=["```"])
    return json.loads(answer)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merge the prompt and test case input, then return the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output


def run_test_case(test_case):
    """Call run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }


def run_eval(dataset):
    """Load dataset and call run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Python Function to Extract AWS Region from S3 URL\n\n```python\nimport re\nfrom urllib.parse import urlparse\n\ndef extract_region_from_s3_url(s3_url: str) -> str or None:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Supports formats:\n    - s3://bucket-name.region.amazonaws.com\n    - https://bucket-name.s3.region.amazonaws.com\n    - https://s3.region.amazonaws.com/bucket-name\n    - s3://bucket-name\n    \n    Args:\n        s3_url (str): The S3 bucket URL\n        \n    Returns:\n        str or None: The AWS region name or None if not found\n        \n    Examples:\n        >>> extract_region_from_s3_url('s3://bucket-name.us-west-2.amazonaws.com')\n        'us-west-2'\n        >>> extract_region_from_s3_url('https://bucket-name.s3.eu-central-1.amazonaws.com')\n        'eu-central-1'\n        >>> extract_region_from_s3_url('s3://bucket-name')\n        None\n    \"\"\"\n    if not s3_url:\n        return None\n    \n    # Pattern 1: s3://bucket-name.region.amazonaws.com\n    pattern1 = r's3://[^.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern1, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 2: https://bucket-name.s3.region.amazonaws.com\n    pattern2 = r'https?://[^.]+\\.s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern2, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 3: https://s3.region.amazonaws.com/bucket-name\n    pattern3 = r'https?://s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern3, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 4: https://s3-region.amazonaws.com/bucket-name (legacy format)\n    pattern4 = r'https?://s3\\-([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern4, s3_url)\n    if match:\n        return match.group(1)\n    \n    return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test cases\n    test_cases = [\n        ('s3://bucket-name.us-west-2.amazonaws.com', 'us-west-2'),\n        ('s3://my-bucket.eu-central-1.amazonaws.com', 'eu-central-1'),\n        ('https://bucket-name.s3.us-east-1.amazonaws.com', 'us-east-1'),\n        ('https://my-bucket.s3.ap-southeast-2.amazonaws.com', 'ap-southeast-2'),\n        ('https://s3.us-west-1.amazonaws.com/bucket-name', 'us-west-1'),\n        ('https://s3-eu-west-1.amazonaws.com/bucket-name', 'eu-west-1'),\n        ('s3://bucket-name', None),\n        ('https://example.com', None),\n        ('', None),\n    ]\n    \n    print(\"Testing extract_region_from_s3_url():\\n\")\n    for url, expected in test_cases:\n        result = extract_region_from_s3_url(url)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} URL: {url}\")\n        print(f\"  Expected: {expected}, Got: {result}\\n\")\n```\n\n## Output:\n```\nTesting extract_region_from",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com'. Return the region name or None if not found."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 GetObject and PutObject\n\nHere's a JSON object that represents an AWS IAM policy with the requested permissions:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-bucket/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: `2012-10-17` is the standard IAM policy language version\n- **Statement**: An array containing policy rules\n- **Effect**: `Allow` grants the specified permissions\n- **Action**: \n  - `s3:GetObject` - allows reading/downloading objects from the bucket\n  - `s3:PutObject` - allows uploading/writing objects to the bucket\n- **Resource**: Uses ARN format targeting all objects (`/*`) within the specific bucket `my-app-bucket`\n\n## Optional: Enhanced Version with Additional Permissions\n\nIf you also want to allow listing the bucket contents, you can add:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-bucket\"\n    }\n  ]\n}\n```\n\nThis adds the ability to list bucket contents, which is often needed alongside GetObject and PutObject operations.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing a user to perform GetObject and PutObject actions on a specific S3 bucket named 'my-app-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS Access Key ID Validation Regex\n\nHere's the regular expression that validates the AWS Access Key ID format:\n\n```regex\n^AKIA[0-9A-Z]{16}$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string anchor |\n| `AKIA` | Literal prefix that all AWS Access Key IDs start with |\n| `[0-9A-Z]{16}` | Exactly 16 characters that are either digits (0-9) or uppercase letters (A-Z) |\n| `$` | End of string anchor |\n\n## Examples\n\n**Valid Access Key IDs:**\n- `AKIAIOSFODNN7EXAMPLE`\n- `AKIAJ7XZ3L2A5BNPQRST`\n- `AKIA1234567890ABCDEF`\n\n**Invalid Access Key IDs:**\n- `AKIA123456789ABCDE` (only 19 characters total)\n- `akiaiosfodnn7example` (lowercase letters)\n- `BKIAIOSFODNN7EXAMPLE` (doesn't start with AKIA)\n- `AKIA12345678-ABCDEF` (contains invalid character `-`)\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst regex = /^AKIA[0-9A-Z]{16}$/;\nconsole.log(regex.test('AKIAIOSFODNN7EXAMPLE')); // true\nconsole.log(regex.test('AKIA123456789ABCDE'));   // false\n```\n\n**Python:**\n```python\nimport re\nregex = r'^AKIA[0-9A-Z]{16}$'\nprint(re.match(regex, 'AKIAIOSFODNN7EXAMPLE'))  # Match object\nprint(re.match(regex, 'AKIA123456789ABCDE'))    # None\n```",
#     "test_case": {
#       "task": "Write a regular expression that validates an AWS Access Key ID format, which consists of 20 uppercase alphanumeric characters starting with 'AKIA'."
#     },
#     "score": 10
#   }
# ]
