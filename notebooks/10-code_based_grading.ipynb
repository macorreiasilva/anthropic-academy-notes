# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_region(url):\n    match = re.search(r's3[.-]([a-z0-9-]+)\\.amazonaws\\.com', url)\n    if match:\n        region = match.group(1)\n        if region == 'amazonaws':\n            return 'us-east-1'\n        return region\n    return None\n\n# Test\nprint(extract_region('s3://my-bucket.s3.us-west-2.amazonaws.com/key'))\nprint(extract_region('s3://my-bucket.s3.eu-central-1.amazonaws.com/key'))\nprint(extract_region('s3://my-bucket.s3.amazonaws.com/key'))\n",
#     "test_case": {
#       "task": "Extract the AWS region from an S3 bucket URL like 's3://my-bucket.s3.us-west-2.amazonaws.com/key'",
#       "format": "regex"
#     },
#     "score": 7.5,
#     "reasoning": "The solution addresses the basic happy path for the given example URL format but has insufficient input validation and limited coverage of real-world S3 URL patterns. The regex pattern would incorrectly match malformed URLs, and there's no verification that extracted values are actual AWS regions. For production use, this needs stricter pattern matching and broader URL format support."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom datetime import datetime\n\ndef parse_cloudwatch_log(log_line: str) -> dict:\n    \"\"\"Parse AWS CloudWatch log entry and extract timestamp, log level, and message.\"\"\"\n    \n    try:\n        # Try parsing as JSON first\n        log_entry = json.loads(log_line)\n        \n        result = {}\n        \n        # Extract timestamp - check common field names\n        timestamp_fields = ['timestamp', '@timestamp', 'time', 'date', 'ts']\n        for field in timestamp_fields:\n            if field in log_entry:\n                result['timestamp'] = log_entry[field]\n                break\n        \n        # Extract log level - check common field names\n        level_fields = ['level', 'levelname', 'severity', 'log_level', 'logLevel']\n        for field in level_fields:\n            if field in log_entry:\n                result['log_level'] = log_entry[field]\n                break\n        \n        # Extract message - check common field names\n        message_fields = ['message', 'msg', 'body', 'text', 'log', 'event']\n        for field in message_fields:\n            if field in log_entry:\n                result['message'] = log_entry[field]\n                break\n        \n        return result\n        \n    except json.JSONDecodeError:\n        # Fallback to regex parsing for non-JSON format\n        pattern = r'(?P<timestamp>\\d{4}-\\d{2}-\\d{2}[T\\s]\\d{2}:\\d{2}:\\d{2}(?:\\.\\d+)?(?:Z|[+-]\\d{2}:\\d{2})?)\\s+\\[?(?P<log_level>DEBUG|INFO|WARN|WARNING|ERROR|CRITICAL|FATAL)\\]?\\s+(?P<message>.*)'\n        match = re.search(pattern, log_line, re.IGNORECASE)\n        \n        if match:\n            return {\n                'timestamp': match.group('timestamp'),\n                'log_level': match.group('log_level').upper(),\n                'message': match.group('message')\n            }\n        \n        return {}\n\n\nif __name__ == \"__main__\":\n    # Test examples\n    json_log = '{\"timestamp\":\"2024-01-15T10:30:45.123Z\",\"level\":\"ERROR\",\"message\":\"Database connection failed\"}'\n    print(parse_cloudwatch_log(json_log))\n    \n    regex_log = '2024-01-15T10:30:45.123Z [ERROR] Database connection failed'\n    print(parse_cloudwatch_log(regex_log))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch log entry and extract the timestamp, log level, and message from a JSON-formatted log line",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution demonstrates good defensive programming with dual parsing strategies and handles common field name variations well. However, it lacks robustness in output consistency (case normalization, missing field handling) and doesn't fully leverage the extracted timestamp data. The regex pattern is well-constructed but the overall implementation would benefit from stricter validation, standardized output format, and clearer failure modes."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Resources\": {\n    \"EC2Role\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2BasicRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"EC2RoleArn\": {\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2Role\",\n          \"Arn\"\n        ]\n      },\n      \"Description\": \"ARN of the EC2 IAM Role\"\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a CloudFormation template snippet in JSON that defines an IAM role with a basic trust policy for EC2 instances",
#       "format": "json"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly defines the core trust policy for EC2 instances, demonstrating understanding of IAM role mechanics and CloudFormation syntax. However, it's incomplete for practical use: an instance profile is essential for EC2 attachment, and the role has no actual permissions. The hardcoded RoleName limits portability. While technically valid for the narrowly-defined task, it would not function as a complete solution in a real deployment scenario."
#   }
# ]
