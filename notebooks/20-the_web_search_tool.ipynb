# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_011CdDymFLSDoYUTXNQwrzr9', content=[TextBlock(citations=None, text='There\'s no single "best" exercise for gaining leg muscle, as the most effective approach typically involves a combination of compound exercises and a proper training program. However, here are some of the most effective leg exercises:\n\n**Compound Movements (Best for Overall Leg Development):**\n- **Squats** - Particularly back squats, front squats, and goblet squats. These engage the quadriceps, glutes, and hamstrings simultaneously and are considered one of the most effective leg-building exercises.\n- **Deadlifts** - Especially Romanian deadlifts and conventional deadlifts, which heavily target the hamstrings, glutes, and lower back.\n- **Leg Press** - A machine exercise that allows you to move heavy weight and targets quads, glutes, and hamstrings.\n- **Lunges** - Both walking and stationary lunges are excellent for unilateral leg development.\n\n**Why These Work:**\n- They involve multiple muscle groups at once\n- They allow you to lift heavy weight progressively\n- Progressive overload (gradually increasing weight/reps) is the key driver of muscle growth\n\n**Key Principles for Leg Muscle Growth:**\n1. **Progressive Overload** - Gradually increase weight, reps, or sets over time\n2. **Adequate Volume** - Perform 10-20 sets per week targeting each leg muscle group\n3. **Proper Nutrition** - Consume sufficient protein and calories to support muscle growth\n4. **Recovery** - Allow 48 hours between intense leg workouts for the same muscle groups\n5. **Consistency** - Train legs regularly, typically 2-3 times per week\n\nMost effective leg-building programs combine 2-3 compound exercises per session with some isolation work (leg curls, leg extensions, calf raises) to address all leg muscles comprehensively.', type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=2228, output_tokens=413, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}, inference_geo='not_available'), stop_details=None)
